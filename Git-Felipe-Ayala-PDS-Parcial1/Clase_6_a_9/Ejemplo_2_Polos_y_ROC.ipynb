# %% [markdown]
# # Ejemplo 2. Polos y ROC

# %%
# Importar las librerias necesarias
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as signal

# %%
def zeropoles(b, a=1):
    # Genera una grafica con los polos y ceros de la función de transferencia
    # y la circunferencia unitaria.
    w,h = sp.freqz(b, a)
    sys1 = sp.lti(b, a)
    ang = np.arange(0.0, 2*np.pi, 0.01)
    xp = np.cos(ang)
    yp = np.sin(ang)
    plt.figure()
    plt.plot(xp, yp, '--')
    plt.plot(sys1.zeros.real, sys1.zeros.imag, 'o')
    plt.plot(sys1.poles.real, sys1.poles.imag, 'x')
    plt.grid()
    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


num = [2, -1, 0]
den = [1, 0, 2]

zeropoles(num, den)
H = signal.TransferFunction(num, den)
t, y = signal.step(H)
plt.plot(t, y)
plt.grid(True)
plt.title('Respuesta al escalón unitario')
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud')
plt.show()


num = [1, 2]
den = [1, 0.5]
zeropoles(num, den)
H = signal.TransferFunction(num, den)
t, y = signal.step(H)
plt.plot(t, y)
plt.grid(True)
plt.title('Respuesta al escalón unitario')
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud')
plt.show()

# %% [markdown]
# Muestra para identificar funciones estables e inestables con el analisis de polos y ceros
